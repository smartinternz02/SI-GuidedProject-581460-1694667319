# %%
#21bce8954
#Aditya Bajaj
import seaborn as sns
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.shape
# Out:
# (51, 8)

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses
# 0      145.08
# 1      133.93
# 2      110.35
# 3      142.39
# 4      165.63

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
df=df.drop(columns='abbrev')

# %%
sns.scatterplot(x="ins_premium",y="ins_losses",data=df)
# Out:
# <AxesSubplot: xlabel='ins_premium', ylabel='ins_losses'>

# %%
sns.lineplot(x="alcohol",y="speeding",data=df,ci=None)
# Out:
# C:\Users\adiforwhat\AppData\Local\Temp\ipykernel_3776\2741251668.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="speeding",data=df,ci=None)
# <AxesSubplot: xlabel='alcohol', ylabel='speeding'>

# %%
sns.displot(df['no_previous'])

# %%
sns.displot(df['not_distracted'])

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses'],
#       dtype='object')

# %%
sns.relplot(x="not_distracted",y="no_previous",data=df,hue="ins_losses")

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="total",y="ins_premium",data=df)
# Out:
# <AxesSubplot: xlabel='total', ylabel='ins_premium'>

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
corr=df.corr()

# %%
corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(corr,annot=True,cmap="Reds")
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection='3d')



# Extracting data
x = df['speeding']
y = df['alcohol']
z = df['ins_losses']

# Creating the scatter plot
ax.scatter(x, y, z, c=z, cmap='viridis', s=50)

# Adding labels
ax.set_xlabel('Speeding Drivers')
ax.set_ylabel('Alcoholic Drivers')
ax.set_zlabel('Insurance Loss')

plt.show()

# %%
sns.displot(df["alcohol"])

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="abbrev",y="alcohol")
# Out:
# <AxesSubplot: xlabel='abbrev', ylabel='alcohol'>

# %% [markdown]
# Can see that ND state has the most car crashes caused due to alcoholism!

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="total",y="abbrev")
# Out:
# <AxesSubplot: xlabel='total', ylabel='abbrev'>

# %% [markdown]
# can infer that ND state has the most car crashes as well!

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="abbrev",y="speeding")
# Out:
# <AxesSubplot: xlabel='abbrev', ylabel='speeding'>

# %% [markdown]
# While hl state has the most car crashes caused due to speeding

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="total",y="speeding",data=df)
# Out:
# <AxesSubplot: xlabel='total', ylabel='speeding'>

# %% [markdown]
# we can notice from the plot that the car crashes will increase always when there is an increment in any of the four factors (alcohol, speeding, no distract, and no previous)
#
# there is no relationship between the changing of alcoholic people and any other category, it seems like the more we have alcoholic, the more we have crashes despite any other factor
#
# from the plot, it is safe to say that focused people (not distracted) have a normal number of crashes even if they were speeding! .. but whenever they drink, crashes happend
#
# we have a strong lead that says doesn't affect crashes that mush, it is mostly on alcohol

# %%
sns.pairplot(data=df,hue="ins_losses")

# %%
sns.jointplot(data= df, y='speeding' , x='alcohol', hue='total')

# %% [markdown]
# proof that speeding and alcohol definitely raises the number of crashes!
